# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cloud_pred=pd.read_csv("/content/cloudpredictionsystemproject.csv")

# %%
cloud_pred.head()
# Out:
#          Date Location  MinimumTemperature  MaximumTemperature  Rainfall  \
# 0  01-12-2008   Albury                13.4                22.9       0.6
# 1  02-12-2008   Albury                 7.4                25.1       0.0
# 2  03-12-2008   Albury                12.9                25.7       0.0
# 3  04-12-2008   Albury                 9.2                28.0       0.0
# 4  05-12-2008   Albury                17.5                32.3       1.0
#
#    Evaporation  Sunshine WindGustDirection  WindGustSpeed WindDirection9am  \
# 0          NaN       NaN                 W           44.0                W
# 1          NaN       NaN               WNW           44.0              NNW
# 2          NaN       NaN               WSW           46.0                W
# 3          NaN       NaN                NE           24.0               SE
# 4          NaN       NaN                 W           41.0              ENE
#
# ...

# %%
cloud_pred.columns
# Out:
# Index(['Date', 'Location', 'MinimumTemperature', 'MaximumTemperature',
#        'Rainfall', 'Evaporation', 'Sunshine', 'WindGustDirection',
#        'WindGustSpeed', 'WindDirection9am', 'WindDirection3pm', 'WindSpeed9am',
#        'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am',
#        'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temperature9am',
#        'Temperature3pm', 'CloudBurst Today', 'CloudBurstTomorrow'],
#       dtype='object')

# %%
cloud_pred.tail()
# Out:
#               Date Location  MinimumTemperature  MaximumTemperature  Rainfall  \
# 145455  21-06-2017    Uluru                 2.8                23.4       0.0
# 145456  22-06-2017    Uluru                 3.6                25.3       0.0
# 145457  23-06-2017    Uluru                 5.4                26.9       0.0
# 145458  24-06-2017    Uluru                 7.8                27.0       0.0
# 145459  25-06-2017    Uluru                14.9                 NaN       0.0
#
#         Evaporation  Sunshine WindGustDirection  WindGustSpeed  \
# 145455          NaN       NaN                 E           31.0
# 145456          NaN       NaN               NNW           22.0
# 145457          NaN       NaN                 N           37.0
# 145458          NaN       NaN                SE           28.0
# 145459          NaN       NaN               NaN            NaN
#
#        WindDirection9am  ... Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
cloud_pred.dtypes
# Out:
# Date                   object
# Location               object
# MinimumTemperature    float64
# MaximumTemperature    float64
# Rainfall              float64
# Evaporation           float64
# Sunshine              float64
# WindGustDirection      object
# WindGustSpeed         float64
# WindDirection9am       object
# WindDirection3pm       object
# WindSpeed9am          float64
# WindSpeed3pm          float64
# Humidity9am           float64
# Humidity3pm           float64
# Pressure9am           float64
# Pressure3pm           float64
# Cloud9am              float64
# Cloud3pm              float64
# Temperature9am        float64
# Temperature3pm        float64
# CloudBurst Today       object
# CloudBurstTomorrow     object
# dtype: object

# %%
cloud_pred['WindDirection9am'].value_counts()
# Out:
# N      11758
# SE      9287
# E       9176
# SSE     9112
# NW      8749
# S       8659
# W       8459
# SW      8423
# NNE     8129
# NNW     7980
# ENE     7836
# NE      7671
# ESE     7630
# SSW     7587
# WNW     7414
# WSW     7024
# Name: WindDirection9am, dtype: int64

# %%
cloud_pred.shape
# Out:
# (145460, 23)

# %%
cloud_pred.isnull().sum()
# Out:
# Date                      0
# Location                  0
# MinimumTemperature     1485
# MaximumTemperature     1261
# Rainfall               3261
# Evaporation           62790
# Sunshine              69835
# WindGustDirection     10326
# WindGustSpeed         10263
# WindDirection9am      10566
# WindDirection3pm       4228
# WindSpeed9am           1767
# WindSpeed3pm           3062
# Humidity9am            2654
# Humidity3pm            4507
# Pressure9am           15065
# Pressure3pm           15028
# Cloud9am              55888
# Cloud3pm              59358
# Temperature9am         1767
# Temperature3pm         3609
# CloudBurst Today       3261
# CloudBurstTomorrow     3267
# dtype: int64

# %%
cloud_pred.dtypes
# Out:
# Date                   object
# Location               object
# MinimumTemperature    float64
# MaximumTemperature    float64
# Rainfall              float64
# Evaporation           float64
# Sunshine              float64
# WindGustDirection      object
# WindGustSpeed         float64
# WindDirection9am       object
# WindDirection3pm       object
# WindSpeed9am          float64
# WindSpeed3pm          float64
# Humidity9am           float64
# Humidity3pm           float64
# Pressure9am           float64
# Pressure3pm           float64
# Cloud9am              float64
# Cloud3pm              float64
# Temperature9am        float64
# Temperature3pm        float64
# CloudBurst Today       object
# CloudBurstTomorrow     object
# dtype: object

# %%
cloud_pred.drop(['Date', 'Pressure9am', 'Pressure3pm','Location'], axis=1, inplace=True)

# %%
cloud_pred['WindGustDirection'].value_counts()
# Out:
# W      9915
# SE     9418
# N      9313
# SSE    9216
# E      9181
# S      9168
# WSW    9069
# SW     8967
# SSW    8736
# WNW    8252
# NW     8122
# ENE    8104
# ESE    7372
# NE     7133
# NNW    6620
# NNE    6548
# Name: WindGustDirection, dtype: int64

# %%
cloud_pred.dropna(inplace=True)

# %%
cloud_pred['WindGustDirection'] = cloud_pred['WindGustDirection'].map( {'E':1,
'N':2,
'W':3,
'S':4,
'SW':5,
'ENE':6,
'SE':7,
'SSW' :8,
'WSW':9,
'ESE':10,
'Ro-ro ship':11,
'SSE':12,
'NE':13,
'WNW':14,
'NW':15,'NNE':16,'NNW':17 } )

# %%
cloud_pred['WindDirection9am'].value_counts()
# Out:
# N      4973
# E      4457
# ENE    3934
# SSE    3901
# SE     3882
# W      3716
# S      3426
# ESE    3401
# NE     3393
# SW     3362
# NNE    3272
# WSW    3046
# NNW    3018
# SSW    2928
# WNW    2921
# NW     2858
# Name: WindDirection9am, dtype: int64

# %%
cloud_pred['WindDirection9am'] = cloud_pred['WindDirection9am'].map( {'E':1,
'N':2,
'W':3,
'S':4,
'SW':5,
'ENE':6,
'SE':7,
'SSW' :8,
'WSW':9,
'ESE':10,
'Ro-ro ship':11,
'SSE':12,
'NE':13,
'WNW':14,
'NW':15,'NNE':16,'NNW':17 } )

# %%
cloud_pred['WindDirection3pm'].value_counts()
# Out:
# SE     4156
# S      4113
# SW     4019
# ENE    3948
# W      3928
# WSW    3863
# E      3758
# ESE    3708
# N      3628
# SSW    3488
# NE     3396
# SSE    3340
# WNW    3202
# NNW    2769
# NW     2729
# NNE    2443
# Name: WindDirection3pm, dtype: int64

# %%
cloud_pred['WindDirection3pm'] = cloud_pred['WindDirection3pm'].map( {'E':1,
'N':2,
'W':3,
'S':4,
'SW':5,
'ENE':6,
'SE':7,
'SSW' :8,
'WSW':9,
'ESE':10,
'Ro-ro ship':11,
'SSE':12,
'NE':13,
'WNW':14,
'NW':15,'NNE':16,'NNW':17 } )

# %%
cloud_pred['CloudBurst Today'].value_counts()
# Out:
# No     43998
# Yes    12490
# Name: CloudBurst Today, dtype: int64

# %%
cloud_pred['CloudBurst Today'] = cloud_pred['CloudBurst Today'].map( {'Yes':1,
'No':0 } )

# %%
cloud_pred['CloudBurstTomorrow'] = cloud_pred['CloudBurstTomorrow'].map( {'Yes':1,
'No':0 } )

# %%
cloud_pred.duplicated
# Out:
# <bound method DataFrame.duplicated of         MinimumTemperature  MaximumTemperature  Rainfall  Evaporation  \
# 6049                  17.9                35.2       0.0         12.0
# 6050                  18.4                28.9       0.0         14.8
# 6052                  19.4                37.6       0.0         10.8
# 6053                  21.9                38.4       0.0         11.4
# 6054                  24.2                41.0       0.0         11.2
# ...                    ...                 ...       ...          ...
# 142298                19.3                33.4       0.0          6.0
# 142299                21.2                32.6       0.0          7.6
# 142300                20.7                32.8       0.0          5.6
# 142301                19.5                31.8       0.0          6.2
# 142302                20.2                31.7       0.0          5.6
#
#         Sunshine  WindGustDirection  WindGustSpeed  WindDirection9am  \
# ...

# %%
cloud_pred.duplicated().sum()
# Out:
# 0

# %%
correlation_matrix=cloud_pred.corr()
correlation_matrix
# Out:
#                     MinimumTemperature  MaximumTemperature  Rainfall  \
# MinimumTemperature            1.000000            0.749567  0.110819
# MaximumTemperature            0.749567            1.000000 -0.070063
# Rainfall                      0.110819           -0.070063  1.000000
# Evaporation                   0.506684            0.650904 -0.077376
# Sunshine                      0.075841            0.463823 -0.246386
# WindGustDirection             0.006158            0.023470 -0.004381
# WindGustSpeed                 0.118045            0.035342  0.106203
# WindDirection9am             -0.031976           -0.026892 -0.004538
# WindDirection3pm              0.022206            0.057306 -0.006193
# WindSpeed9am                  0.108535           -0.008233  0.050499
# WindSpeed3pm                  0.137097            0.012054  0.044093
# Humidity9am                  -0.174767           -0.495753  0.263819
# Humidity3pm                   0.070929           -0.448127  0.277649
# ...

# %%
corr=cloud_pred.corr()
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(corr, annot=True, ax=ax, cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,7))
plt.pie(x=cloud_pred['CloudBurst Today'].value_counts().values,
        labels=cloud_pred['CloudBurst Today'].value_counts().index,
        autopct='%2.2f%%')
plt.title("CloudBurst Detection based on today\'s weather")

plt.show()

# %%
plt.figure(figsize=(10,7))
plt.pie(x=cloud_pred['CloudBurstTomorrow'].value_counts().values,
        labels=cloud_pred['CloudBurstTomorrow'].value_counts().index,
        autopct='%2.2f%%')
plt.title("CloudBurst Detection based on today\'s weather for Tomorrow")

plt.show()

# %%
cloud_pred.dtypes
# Out:
# MinimumTemperature    float64
# MaximumTemperature    float64
# Rainfall              float64
# Evaporation           float64
# Sunshine              float64
# WindGustDirection       int64
# WindGustSpeed         float64
# WindDirection9am        int64
# WindDirection3pm        int64
# WindSpeed9am          float64
# WindSpeed3pm          float64
# Humidity9am           float64
# Humidity3pm           float64
# Cloud9am              float64
# Cloud3pm              float64
# Temperature9am        float64
# Temperature3pm        float64
# CloudBurst Today        int64
# CloudBurstTomorrow      int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X1 = cloud_pred.drop(['CloudBurst Today', 'CloudBurstTomorrow'], axis=1)
y1 = cloud_pred[['CloudBurst Today']]

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model1 = DecisionTreeClassifier( max_depth=4, random_state=42)

# %%
model1.fit(X1_train,y1_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %%
pred_dt = model1.predict(X1_test)

# %%
dt = accuracy_score(y1_test, pred_dt)
print(dt)
# Out:
# 1.0

# %%
from sklearn.tree import DecisionTreeClassifier
# Creating model object
model1 = DecisionTreeClassifier( max_depth=4, random_state=42)
# Training Model
model1.fit(X1_train,y1_train)
DecisionTreeClassifier(max_depth=4, random_state=42)
# Making Prediction
pred_dt = model1.predict(X1_test)
# Calculating Accuracy Score
dt = accuracy_score(y1_test, pred_dt)
print(dt)
# Out:
# 1.0

# %%
predictions1 = model1.predict(X1_test)

# %%
cloud_pred.to_csv('your_processed_data.csv', index=False)

# %%
new_data_point = [[24.1,41.4,1.6,12.6,12.3,6,39,13,9,17,7,50,21,0,4,28.2,38.8]]
# Make predictions
prediction = model1.predict(new_data_point)
print("Prediction:", prediction)
# Out:
# Prediction: [1]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from IPython.display import Image, display, HTML

# Assuming you have a dictionary mapping sentiment types to image paths and GIF paths
cloudburst_predictions_1 = {
    0: {'gif': '/content/clear weather.gif'},
    1: {'gif': '/content/thunder.gif'},
}

new_data_point_1 = [[16.1,19.1,26,6.6,0,10,54,10,10,28,19,81,93,7,7,17.1,17]]  # Provide the features of your new data point
prediction_1 = model1.predict(new_data_point_1)

print("Prediction:", prediction_1)


# Check the prediction value and display the corresponding GIF
if prediction_1 == 0:
    predict="There will be NO cloudburst today"
    highlighted_output = HTML(f"The predicted output is: <span style='color: red; font-weight: bold;'>{predict}</span>")
    display(highlighted_output)
    gif_path = cloudburst_predictions_1[0]['gif']
    display(Image(filename=gif_path))
elif prediction_1 == 1:
    predict="There will be CLOUDBURST today"
    highlighted_output = HTML(f"The predicted output is: <span style='color: red; font-weight: bold;'>{predict}</span>")
    display(highlighted_output)
    print("There will be cloudburst Today")
    gif_path = cloudburst_predictions_1[1]['gif']
    display(Image(filename=gif_path))
else:
    print("Invalid prediction value. No corresponding GIF found.")
# Out:
# Prediction: [1]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# The predicted output is: <span style='color: red; font-weight: bold;'>There will be CLOUDBURST today</span>
# There will be cloudburst Today

# %%
X2 = cloud_pred.drop(['CloudBurst Today', 'CloudBurstTomorrow'], axis=1)
y2 = cloud_pred[['CloudBurstTomorrow']]

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model2 = DecisionTreeClassifier( max_depth=4, random_state=42)

# %%
model2.fit(X2_train,y2_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %%
pred_dt = model2.predict(X2_test)

# %%
dt = accuracy_score(y2_test, pred_dt)
print(dt)
# Out:
# 0.8393412723956657

# %%
from sklearn.tree import DecisionTreeClassifier
# Creating model object
model2 = DecisionTreeClassifier( max_depth=4, random_state=42)
# Training Model
model2.fit(X2_train,y2_train)
DecisionTreeClassifier(max_depth=4, random_state=42)
# Making Prediction
pred_dt = model2.predict(X2_test)
# Calculating Accuracy Score
dt = accuracy_score(y2_test, pred_dt)
print(dt)
# Out:
# 0.8393412723956657

# %%
predictions = model2.predict(X1_test)

# %%
predictions2=model2.predict(X2_test)

# %%
new_data_point2 = [[24.1,41.4,1.6,12.6,12.3,6,39,13,9,17,7,50,21,0,4,28.2,38.8]]
# Make predictions
prediction2 = model2.predict(new_data_point)
print("Prediction:", prediction2)
# Out:
# Prediction: [0]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from IPython.display import Image, display, HTML

# Assuming you have a dictionary mapping sentiment types to image paths and GIF paths
cloudburst_predictions_1 = {
    0: {'gif': '/content/clear weather.gif'},
    1: {'gif': '/content/thunder.gif'},
}

new_data_point_2 = [[16.1,19.1,26,6.6,0,10,54,10,10,28,19,81,93,7,7,17.1,17]]  # Provide the features of your new data point
prediction_2 = model2.predict(new_data_point_2)

print("Prediction:", prediction_2)
# Check the prediction value and display the corresponding GIF
if prediction_2 == 0:
    predict="There will be NO cloudburst today"
    highlighted_output = HTML(f"The predicted output is: <span style='color: red; font-weight: bold;'>{predict}</span>")
    display(highlighted_output)
    gif_path = cloudburst_predictions_1[0]['gif']
    display(Image(filename=gif_path))
elif prediction_2 == 1:
    predict="There will be CLOUDBURST tomorrow"
    highlighted_output = HTML(f"The predicted output is: <span style='color: red; font-weight: bold;'>{predict}</span>")
    display(highlighted_output)
    print("There will be cloudburst tomorrow")
    gif_path = cloudburst_predictions_1[1]['gif']
    display(Image(filename=gif_path))
else:
    print("Invalid prediction value. No corresponding GIF found.")
# Out:
# Prediction: [1]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# The predicted output is: <span style='color: red; font-weight: bold;'>There will be CLOUDBURST tomorrow</span>
# There will be cloudburst tomorrow
